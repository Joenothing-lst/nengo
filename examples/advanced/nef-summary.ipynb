# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="678992013" href="javascript:toggle_input_678992013()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_678992013;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_678992013 = document.getElementById("678992013");
#                 var cell = link_678992013;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_678992013;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_678992013 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_678992013 = cell.previousElementSibling;
#                 }
#                 input_678992013.style.display = "none"; // hide
#
#                 toggle_input_678992013 = function() {
#                     if (input_678992013.style.display == "none") {
#                         input_678992013.style.display = ""; // show
#                         link_678992013.innerHTML = "Hide Input";
#                     } else {
#                         input_678992013.style.display = "none"; // hide
#                         link_678992013.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_678992013 = $("a[id='678992013']");
#                 var cell_678992013 = link_678992013.parents("div.cell:first");
#                 if (cell_678992013.length == 0) {
#                     cell_678992013 = link_678992013.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_678992013 = cell_678992013.children("div.input");
#                 if (input_678992013.length == 0) {
#                     input_678992013 = cell_678992013.prev("div.nbinput");
#                 }
#                 input_678992013.hide();
#
#                 toggle_input_678992013 = function() {
#                     if (input_678992013.is(':hidden')) {
#                         input_678992013.slideDown();
#                         link_678992013[0].innerHTML = "Hide Input";
#                     } else {
#                         input_678992013.slideUp();
#                         link_678992013[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1955767592" href="javascript:toggle_input_1955767592()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1955767592;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1955767592 = document.getElementById("1955767592");
#                 var cell = link_1955767592;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1955767592;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1955767592 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1955767592 = cell.previousElementSibling;
#                 }
#                 input_1955767592.style.display = "none"; // hide
#
#                 toggle_input_1955767592 = function() {
#                     if (input_1955767592.style.display == "none") {
#                         input_1955767592.style.display = ""; // show
#                         link_1955767592.innerHTML = "Hide Input";
#                     } else {
#                         input_1955767592.style.display = "none"; // hide
#                         link_1955767592.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1955767592 = $("a[id='1955767592']");
#                 var cell_1955767592 = link_1955767592.parents("div.cell:first");
#                 if (cell_1955767592.length == 0) {
#                     cell_1955767592 = link_1955767592.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1955767592 = cell_1955767592.children("div.input");
#                 if (input_1955767592.length == 0) {
#                     input_1955767592 = cell_1955767592.prev("div.nbinput");
#                 }
#                 input_1955767592.hide();
#
#                 toggle_input_1955767592 = function() {
#                     if (input_1955767592.is(':hidden')) {
#                         input_1955767592.slideDown();
#                         link_1955767592[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1955767592.slideUp();
#                         link_1955767592[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1842053749" href="javascript:toggle_input_1842053749()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1842053749;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1842053749 = document.getElementById("1842053749");
#                 var cell = link_1842053749;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1842053749;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1842053749 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1842053749 = cell.previousElementSibling;
#                 }
#                 input_1842053749.style.display = "none"; // hide
#
#                 toggle_input_1842053749 = function() {
#                     if (input_1842053749.style.display == "none") {
#                         input_1842053749.style.display = ""; // show
#                         link_1842053749.innerHTML = "Hide Input";
#                     } else {
#                         input_1842053749.style.display = "none"; // hide
#                         link_1842053749.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1842053749 = $("a[id='1842053749']");
#                 var cell_1842053749 = link_1842053749.parents("div.cell:first");
#                 if (cell_1842053749.length == 0) {
#                     cell_1842053749 = link_1842053749.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1842053749 = cell_1842053749.children("div.input");
#                 if (input_1842053749.length == 0) {
#                     input_1842053749 = cell_1842053749.prev("div.nbinput");
#                 }
#                 input_1842053749.hide();
#
#                 toggle_input_1842053749 = function() {
#                     if (input_1842053749.is(':hidden')) {
#                         input_1842053749.slideDown();
#                         link_1842053749[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1842053749.slideUp();
#                         link_1842053749[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1892050095" href="javascript:toggle_input_1892050095()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1892050095;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1892050095 = document.getElementById("1892050095");
#                 var cell = link_1892050095;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1892050095;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1892050095 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1892050095 = cell.previousElementSibling;
#                 }
#                 input_1892050095.style.display = "none"; // hide
#
#                 toggle_input_1892050095 = function() {
#                     if (input_1892050095.style.display == "none") {
#                         input_1892050095.style.display = ""; // show
#                         link_1892050095.innerHTML = "Hide Input";
#                     } else {
#                         input_1892050095.style.display = "none"; // hide
#                         link_1892050095.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1892050095 = $("a[id='1892050095']");
#                 var cell_1892050095 = link_1892050095.parents("div.cell:first");
#                 if (cell_1892050095.length == 0) {
#                     cell_1892050095 = link_1892050095.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1892050095 = cell_1892050095.children("div.input");
#                 if (input_1892050095.length == 0) {
#                     input_1892050095 = cell_1892050095.prev("div.nbinput");
#                 }
#                 input_1892050095.hide();
#
#                 toggle_input_1892050095 = function() {
#                     if (input_1892050095.is(':hidden')) {
#                         input_1892050095.slideDown();
#                         link_1892050095[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1892050095.slideUp();
#                         link_1892050095[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1540196170" href="javascript:toggle_input_1540196170()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1540196170;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1540196170 = document.getElementById("1540196170");
#                 var cell = link_1540196170;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1540196170;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1540196170 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1540196170 = cell.previousElementSibling;
#                 }
#                 input_1540196170.style.display = "none"; // hide
#
#                 toggle_input_1540196170 = function() {
#                     if (input_1540196170.style.display == "none") {
#                         input_1540196170.style.display = ""; // show
#                         link_1540196170.innerHTML = "Hide Input";
#                     } else {
#                         input_1540196170.style.display = "none"; // hide
#                         link_1540196170.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1540196170 = $("a[id='1540196170']");
#                 var cell_1540196170 = link_1540196170.parents("div.cell:first");
#                 if (cell_1540196170.length == 0) {
#                     cell_1540196170 = link_1540196170.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1540196170 = cell_1540196170.children("div.input");
#                 if (input_1540196170.length == 0) {
#                     input_1540196170 = cell_1540196170.prev("div.nbinput");
#                 }
#                 input_1540196170.hide();
#
#                 toggle_input_1540196170 = function() {
#                     if (input_1540196170.is(':hidden')) {
#                         input_1540196170.slideDown();
#                         link_1540196170[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1540196170.slideUp();
#                         link_1540196170[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1950277459" href="javascript:toggle_input_1950277459()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1950277459;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1950277459 = document.getElementById("1950277459");
#                 var cell = link_1950277459;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1950277459;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1950277459 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1950277459 = cell.previousElementSibling;
#                 }
#                 input_1950277459.style.display = "none"; // hide
#
#                 toggle_input_1950277459 = function() {
#                     if (input_1950277459.style.display == "none") {
#                         input_1950277459.style.display = ""; // show
#                         link_1950277459.innerHTML = "Hide Input";
#                     } else {
#                         input_1950277459.style.display = "none"; // hide
#                         link_1950277459.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1950277459 = $("a[id='1950277459']");
#                 var cell_1950277459 = link_1950277459.parents("div.cell:first");
#                 if (cell_1950277459.length == 0) {
#                     cell_1950277459 = link_1950277459.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1950277459 = cell_1950277459.children("div.input");
#                 if (input_1950277459.length == 0) {
#                     input_1950277459 = cell_1950277459.prev("div.nbinput");
#                 }
#                 input_1950277459.hide();
#
#                 toggle_input_1950277459 = function() {
#                     if (input_1950277459.is(':hidden')) {
#                         input_1950277459.slideDown();
#                         link_1950277459[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1950277459.slideUp();
#                         link_1950277459[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="654524481" href="javascript:toggle_input_654524481()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_654524481;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_654524481 = document.getElementById("654524481");
#                 var cell = link_654524481;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_654524481;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_654524481 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_654524481 = cell.previousElementSibling;
#                 }
#                 input_654524481.style.display = "none"; // hide
#
#                 toggle_input_654524481 = function() {
#                     if (input_654524481.style.display == "none") {
#                         input_654524481.style.display = ""; // show
#                         link_654524481.innerHTML = "Hide Input";
#                     } else {
#                         input_654524481.style.display = "none"; // hide
#                         link_654524481.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_654524481 = $("a[id='654524481']");
#                 var cell_654524481 = link_654524481.parents("div.cell:first");
#                 if (cell_654524481.length == 0) {
#                     cell_654524481 = link_654524481.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_654524481 = cell_654524481.children("div.input");
#                 if (input_654524481.length == 0) {
#                     input_654524481 = cell_654524481.prev("div.nbinput");
#                 }
#                 input_654524481.hide();
#
#                 toggle_input_654524481 = function() {
#                     if (input_654524481.is(':hidden')) {
#                         input_654524481.slideDown();
#                         link_654524481[0].innerHTML = "Hide Input";
#                     } else {
#                         input_654524481.slideUp();
#                         link_654524481[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="668659053" href="javascript:toggle_input_668659053()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_668659053;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_668659053 = document.getElementById("668659053");
#                 var cell = link_668659053;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_668659053;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_668659053 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_668659053 = cell.previousElementSibling;
#                 }
#                 input_668659053.style.display = "none"; // hide
#
#                 toggle_input_668659053 = function() {
#                     if (input_668659053.style.display == "none") {
#                         input_668659053.style.display = ""; // show
#                         link_668659053.innerHTML = "Hide Input";
#                     } else {
#                         input_668659053.style.display = "none"; // hide
#                         link_668659053.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_668659053 = $("a[id='668659053']");
#                 var cell_668659053 = link_668659053.parents("div.cell:first");
#                 if (cell_668659053.length == 0) {
#                     cell_668659053 = link_668659053.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_668659053 = cell_668659053.children("div.input");
#                 if (input_668659053.length == 0) {
#                     input_668659053 = cell_668659053.prev("div.nbinput");
#                 }
#                 input_668659053.hide();
#
#                 toggle_input_668659053 = function() {
#                     if (input_668659053.is(':hidden')) {
#                         input_668659053.slideDown();
#                         link_668659053[0].innerHTML = "Hide Input";
#                     } else {
#                         input_668659053.slideUp();
#                         link_668659053[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="216226956" href="javascript:toggle_input_216226956()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_216226956;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_216226956 = document.getElementById("216226956");
#                 var cell = link_216226956;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_216226956;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_216226956 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_216226956 = cell.previousElementSibling;
#                 }
#                 input_216226956.style.display = "none"; // hide
#
#                 toggle_input_216226956 = function() {
#                     if (input_216226956.style.display == "none") {
#                         input_216226956.style.display = ""; // show
#                         link_216226956.innerHTML = "Hide Input";
#                     } else {
#                         input_216226956.style.display = "none"; // hide
#                         link_216226956.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_216226956 = $("a[id='216226956']");
#                 var cell_216226956 = link_216226956.parents("div.cell:first");
#                 if (cell_216226956.length == 0) {
#                     cell_216226956 = link_216226956.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_216226956 = cell_216226956.children("div.input");
#                 if (input_216226956.length == 0) {
#                     input_216226956 = cell_216226956.prev("div.nbinput");
#                 }
#                 input_216226956.hide();
#
#                 toggle_input_216226956 = function() {
#                     if (input_216226956.is(':hidden')) {
#                         input_216226956.slideDown();
#                         link_216226956[0].innerHTML = "Hide Input";
#                     } else {
#                         input_216226956.slideUp();
#                         link_216226956[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="38866980" href="javascript:toggle_input_38866980()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_38866980;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_38866980 = document.getElementById("38866980");
#                 var cell = link_38866980;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_38866980;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_38866980 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_38866980 = cell.previousElementSibling;
#                 }
#                 input_38866980.style.display = "none"; // hide
#
#                 toggle_input_38866980 = function() {
#                     if (input_38866980.style.display == "none") {
#                         input_38866980.style.display = ""; // show
#                         link_38866980.innerHTML = "Hide Input";
#                     } else {
#                         input_38866980.style.display = "none"; // hide
#                         link_38866980.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_38866980 = $("a[id='38866980']");
#                 var cell_38866980 = link_38866980.parents("div.cell:first");
#                 if (cell_38866980.length == 0) {
#                     cell_38866980 = link_38866980.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_38866980 = cell_38866980.children("div.input");
#                 if (input_38866980.length == 0) {
#                     input_38866980 = cell_38866980.prev("div.nbinput");
#                 }
#                 input_38866980.hide();
#
#                 toggle_input_38866980 = function() {
#                     if (input_38866980.is(':hidden')) {
#                         input_38866980.slideDown();
#                         link_38866980[0].innerHTML = "Hide Input";
#                     } else {
#                         input_38866980.slideUp();
#                         link_38866980[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1554988704" href="javascript:toggle_input_1554988704()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1554988704;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1554988704 = document.getElementById("1554988704");
#                 var cell = link_1554988704;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1554988704;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1554988704 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1554988704 = cell.previousElementSibling;
#                 }
#                 input_1554988704.style.display = "none"; // hide
#
#                 toggle_input_1554988704 = function() {
#                     if (input_1554988704.style.display == "none") {
#                         input_1554988704.style.display = ""; // show
#                         link_1554988704.innerHTML = "Hide Input";
#                     } else {
#                         input_1554988704.style.display = "none"; // hide
#                         link_1554988704.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1554988704 = $("a[id='1554988704']");
#                 var cell_1554988704 = link_1554988704.parents("div.cell:first");
#                 if (cell_1554988704.length == 0) {
#                     cell_1554988704 = link_1554988704.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1554988704 = cell_1554988704.children("div.input");
#                 if (input_1554988704.length == 0) {
#                     input_1554988704 = cell_1554988704.prev("div.nbinput");
#                 }
#                 input_1554988704.hide();
#
#                 toggle_input_1554988704 = function() {
#                     if (input_1554988704.is(':hidden')) {
#                         input_1554988704.slideDown();
#                         link_1554988704[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1554988704.slideUp();
#                         link_1554988704[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1037886295" href="javascript:toggle_input_1037886295()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1037886295;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1037886295 = document.getElementById("1037886295");
#                 var cell = link_1037886295;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1037886295;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1037886295 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1037886295 = cell.previousElementSibling;
#                 }
#                 input_1037886295.style.display = "none"; // hide
#
#                 toggle_input_1037886295 = function() {
#                     if (input_1037886295.style.display == "none") {
#                         input_1037886295.style.display = ""; // show
#                         link_1037886295.innerHTML = "Hide Input";
#                     } else {
#                         input_1037886295.style.display = "none"; // hide
#                         link_1037886295.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1037886295 = $("a[id='1037886295']");
#                 var cell_1037886295 = link_1037886295.parents("div.cell:first");
#                 if (cell_1037886295.length == 0) {
#                     cell_1037886295 = link_1037886295.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1037886295 = cell_1037886295.children("div.input");
#                 if (input_1037886295.length == 0) {
#                     input_1037886295 = cell_1037886295.prev("div.nbinput");
#                 }
#                 input_1037886295.hide();
#
#                 toggle_input_1037886295 = function() {
#                     if (input_1037886295.is(':hidden')) {
#                         input_1037886295.slideDown();
#                         link_1037886295[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1037886295.slideUp();
#                         link_1037886295[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1876000733" href="javascript:toggle_input_1876000733()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1876000733;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1876000733 = document.getElementById("1876000733");
#                 var cell = link_1876000733;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1876000733;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1876000733 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1876000733 = cell.previousElementSibling;
#                 }
#                 input_1876000733.style.display = "none"; // hide
#
#                 toggle_input_1876000733 = function() {
#                     if (input_1876000733.style.display == "none") {
#                         input_1876000733.style.display = ""; // show
#                         link_1876000733.innerHTML = "Hide Input";
#                     } else {
#                         input_1876000733.style.display = "none"; // hide
#                         link_1876000733.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1876000733 = $("a[id='1876000733']");
#                 var cell_1876000733 = link_1876000733.parents("div.cell:first");
#                 if (cell_1876000733.length == 0) {
#                     cell_1876000733 = link_1876000733.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1876000733 = cell_1876000733.children("div.input");
#                 if (input_1876000733.length == 0) {
#                     input_1876000733 = cell_1876000733.prev("div.nbinput");
#                 }
#                 input_1876000733.hide();
#
#                 toggle_input_1876000733 = function() {
#                     if (input_1876000733.is(':hidden')) {
#                         input_1876000733.slideDown();
#                         link_1876000733[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1876000733.slideUp();
#                         link_1876000733[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
