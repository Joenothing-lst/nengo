# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1734622518" href="javascript:toggle_input_1734622518()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1734622518;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1734622518 = document.getElementById("1734622518");
#                 var cell = link_1734622518;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1734622518;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1734622518 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1734622518 = cell.previousElementSibling;
#                 }
#                 input_1734622518.style.display = "none"; // hide
#
#                 toggle_input_1734622518 = function() {
#                     if (input_1734622518.style.display == "none") {
#                         input_1734622518.style.display = ""; // show
#                         link_1734622518.innerHTML = "Hide Input";
#                     } else {
#                         input_1734622518.style.display = "none"; // hide
#                         link_1734622518.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1734622518 = $("a[id='1734622518']");
#                 var cell_1734622518 = link_1734622518.parents("div.cell:first");
#                 if (cell_1734622518.length == 0) {
#                     cell_1734622518 = link_1734622518.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1734622518 = cell_1734622518.children("div.input");
#                 if (input_1734622518.length == 0) {
#                     input_1734622518 = cell_1734622518.prev("div.nbinput");
#                 }
#                 input_1734622518.hide();
#
#                 toggle_input_1734622518 = function() {
#                     if (input_1734622518.is(':hidden')) {
#                         input_1734622518.slideDown();
#                         link_1734622518[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1734622518.slideUp();
#                         link_1734622518[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1747363915" href="javascript:toggle_input_1747363915()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1747363915;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1747363915 = document.getElementById("1747363915");
#                 var cell = link_1747363915;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1747363915;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1747363915 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1747363915 = cell.previousElementSibling;
#                 }
#                 input_1747363915.style.display = "none"; // hide
#
#                 toggle_input_1747363915 = function() {
#                     if (input_1747363915.style.display == "none") {
#                         input_1747363915.style.display = ""; // show
#                         link_1747363915.innerHTML = "Hide Input";
#                     } else {
#                         input_1747363915.style.display = "none"; // hide
#                         link_1747363915.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1747363915 = $("a[id='1747363915']");
#                 var cell_1747363915 = link_1747363915.parents("div.cell:first");
#                 if (cell_1747363915.length == 0) {
#                     cell_1747363915 = link_1747363915.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1747363915 = cell_1747363915.children("div.input");
#                 if (input_1747363915.length == 0) {
#                     input_1747363915 = cell_1747363915.prev("div.nbinput");
#                 }
#                 input_1747363915.hide();
#
#                 toggle_input_1747363915 = function() {
#                     if (input_1747363915.is(':hidden')) {
#                         input_1747363915.slideDown();
#                         link_1747363915[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1747363915.slideUp();
#                         link_1747363915[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="835247844" href="javascript:toggle_input_835247844()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_835247844;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_835247844 = document.getElementById("835247844");
#                 var cell = link_835247844;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_835247844;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_835247844 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_835247844 = cell.previousElementSibling;
#                 }
#                 input_835247844.style.display = "none"; // hide
#
#                 toggle_input_835247844 = function() {
#                     if (input_835247844.style.display == "none") {
#                         input_835247844.style.display = ""; // show
#                         link_835247844.innerHTML = "Hide Input";
#                     } else {
#                         input_835247844.style.display = "none"; // hide
#                         link_835247844.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_835247844 = $("a[id='835247844']");
#                 var cell_835247844 = link_835247844.parents("div.cell:first");
#                 if (cell_835247844.length == 0) {
#                     cell_835247844 = link_835247844.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_835247844 = cell_835247844.children("div.input");
#                 if (input_835247844.length == 0) {
#                     input_835247844 = cell_835247844.prev("div.nbinput");
#                 }
#                 input_835247844.hide();
#
#                 toggle_input_835247844 = function() {
#                     if (input_835247844.is(':hidden')) {
#                         input_835247844.slideDown();
#                         link_835247844[0].innerHTML = "Hide Input";
#                     } else {
#                         input_835247844.slideUp();
#                         link_835247844[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="899684105" href="javascript:toggle_input_899684105()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_899684105;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_899684105 = document.getElementById("899684105");
#                 var cell = link_899684105;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_899684105;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_899684105 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_899684105 = cell.previousElementSibling;
#                 }
#                 input_899684105.style.display = "none"; // hide
#
#                 toggle_input_899684105 = function() {
#                     if (input_899684105.style.display == "none") {
#                         input_899684105.style.display = ""; // show
#                         link_899684105.innerHTML = "Hide Input";
#                     } else {
#                         input_899684105.style.display = "none"; // hide
#                         link_899684105.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_899684105 = $("a[id='899684105']");
#                 var cell_899684105 = link_899684105.parents("div.cell:first");
#                 if (cell_899684105.length == 0) {
#                     cell_899684105 = link_899684105.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_899684105 = cell_899684105.children("div.input");
#                 if (input_899684105.length == 0) {
#                     input_899684105 = cell_899684105.prev("div.nbinput");
#                 }
#                 input_899684105.hide();
#
#                 toggle_input_899684105 = function() {
#                     if (input_899684105.is(':hidden')) {
#                         input_899684105.slideDown();
#                         link_899684105[0].innerHTML = "Hide Input";
#                     } else {
#                         input_899684105.slideUp();
#                         link_899684105[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1652032990" href="javascript:toggle_input_1652032990()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1652032990;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1652032990 = document.getElementById("1652032990");
#                 var cell = link_1652032990;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1652032990;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1652032990 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1652032990 = cell.previousElementSibling;
#                 }
#                 input_1652032990.style.display = "none"; // hide
#
#                 toggle_input_1652032990 = function() {
#                     if (input_1652032990.style.display == "none") {
#                         input_1652032990.style.display = ""; // show
#                         link_1652032990.innerHTML = "Hide Input";
#                     } else {
#                         input_1652032990.style.display = "none"; // hide
#                         link_1652032990.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1652032990 = $("a[id='1652032990']");
#                 var cell_1652032990 = link_1652032990.parents("div.cell:first");
#                 if (cell_1652032990.length == 0) {
#                     cell_1652032990 = link_1652032990.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1652032990 = cell_1652032990.children("div.input");
#                 if (input_1652032990.length == 0) {
#                     input_1652032990 = cell_1652032990.prev("div.nbinput");
#                 }
#                 input_1652032990.hide();
#
#                 toggle_input_1652032990 = function() {
#                     if (input_1652032990.is(':hidden')) {
#                         input_1652032990.slideDown();
#                         link_1652032990[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1652032990.slideUp();
#                         link_1652032990[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1082039071" href="javascript:toggle_input_1082039071()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1082039071;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1082039071 = document.getElementById("1082039071");
#                 var cell = link_1082039071;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1082039071;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1082039071 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1082039071 = cell.previousElementSibling;
#                 }
#                 input_1082039071.style.display = "none"; // hide
#
#                 toggle_input_1082039071 = function() {
#                     if (input_1082039071.style.display == "none") {
#                         input_1082039071.style.display = ""; // show
#                         link_1082039071.innerHTML = "Hide Input";
#                     } else {
#                         input_1082039071.style.display = "none"; // hide
#                         link_1082039071.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1082039071 = $("a[id='1082039071']");
#                 var cell_1082039071 = link_1082039071.parents("div.cell:first");
#                 if (cell_1082039071.length == 0) {
#                     cell_1082039071 = link_1082039071.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1082039071 = cell_1082039071.children("div.input");
#                 if (input_1082039071.length == 0) {
#                     input_1082039071 = cell_1082039071.prev("div.nbinput");
#                 }
#                 input_1082039071.hide();
#
#                 toggle_input_1082039071 = function() {
#                     if (input_1082039071.is(':hidden')) {
#                         input_1082039071.slideDown();
#                         link_1082039071[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1082039071.slideUp();
#                         link_1082039071[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1277610835" href="javascript:toggle_input_1277610835()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1277610835;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1277610835 = document.getElementById("1277610835");
#                 var cell = link_1277610835;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1277610835;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1277610835 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1277610835 = cell.previousElementSibling;
#                 }
#                 input_1277610835.style.display = "none"; // hide
#
#                 toggle_input_1277610835 = function() {
#                     if (input_1277610835.style.display == "none") {
#                         input_1277610835.style.display = ""; // show
#                         link_1277610835.innerHTML = "Hide Input";
#                     } else {
#                         input_1277610835.style.display = "none"; // hide
#                         link_1277610835.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1277610835 = $("a[id='1277610835']");
#                 var cell_1277610835 = link_1277610835.parents("div.cell:first");
#                 if (cell_1277610835.length == 0) {
#                     cell_1277610835 = link_1277610835.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1277610835 = cell_1277610835.children("div.input");
#                 if (input_1277610835.length == 0) {
#                     input_1277610835 = cell_1277610835.prev("div.nbinput");
#                 }
#                 input_1277610835.hide();
#
#                 toggle_input_1277610835 = function() {
#                     if (input_1277610835.is(':hidden')) {
#                         input_1277610835.slideDown();
#                         link_1277610835[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1277610835.slideUp();
#                         link_1277610835[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1030652499" href="javascript:toggle_input_1030652499()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1030652499;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1030652499 = document.getElementById("1030652499");
#                 var cell = link_1030652499;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1030652499;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1030652499 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1030652499 = cell.previousElementSibling;
#                 }
#                 input_1030652499.style.display = "none"; // hide
#
#                 toggle_input_1030652499 = function() {
#                     if (input_1030652499.style.display == "none") {
#                         input_1030652499.style.display = ""; // show
#                         link_1030652499.innerHTML = "Hide Input";
#                     } else {
#                         input_1030652499.style.display = "none"; // hide
#                         link_1030652499.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1030652499 = $("a[id='1030652499']");
#                 var cell_1030652499 = link_1030652499.parents("div.cell:first");
#                 if (cell_1030652499.length == 0) {
#                     cell_1030652499 = link_1030652499.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1030652499 = cell_1030652499.children("div.input");
#                 if (input_1030652499.length == 0) {
#                     input_1030652499 = cell_1030652499.prev("div.nbinput");
#                 }
#                 input_1030652499.hide();
#
#                 toggle_input_1030652499 = function() {
#                     if (input_1030652499.is(':hidden')) {
#                         input_1030652499.slideDown();
#                         link_1030652499[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1030652499.slideUp();
#                         link_1030652499[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="721322150" href="javascript:toggle_input_721322150()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_721322150;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_721322150 = document.getElementById("721322150");
#                 var cell = link_721322150;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_721322150;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_721322150 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_721322150 = cell.previousElementSibling;
#                 }
#                 input_721322150.style.display = "none"; // hide
#
#                 toggle_input_721322150 = function() {
#                     if (input_721322150.style.display == "none") {
#                         input_721322150.style.display = ""; // show
#                         link_721322150.innerHTML = "Hide Input";
#                     } else {
#                         input_721322150.style.display = "none"; // hide
#                         link_721322150.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_721322150 = $("a[id='721322150']");
#                 var cell_721322150 = link_721322150.parents("div.cell:first");
#                 if (cell_721322150.length == 0) {
#                     cell_721322150 = link_721322150.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_721322150 = cell_721322150.children("div.input");
#                 if (input_721322150.length == 0) {
#                     input_721322150 = cell_721322150.prev("div.nbinput");
#                 }
#                 input_721322150.hide();
#
#                 toggle_input_721322150 = function() {
#                     if (input_721322150.is(':hidden')) {
#                         input_721322150.slideDown();
#                         link_721322150[0].innerHTML = "Hide Input";
#                     } else {
#                         input_721322150.slideUp();
#                         link_721322150[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1734220557" href="javascript:toggle_input_1734220557()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1734220557;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1734220557 = document.getElementById("1734220557");
#                 var cell = link_1734220557;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1734220557;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1734220557 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1734220557 = cell.previousElementSibling;
#                 }
#                 input_1734220557.style.display = "none"; // hide
#
#                 toggle_input_1734220557 = function() {
#                     if (input_1734220557.style.display == "none") {
#                         input_1734220557.style.display = ""; // show
#                         link_1734220557.innerHTML = "Hide Input";
#                     } else {
#                         input_1734220557.style.display = "none"; // hide
#                         link_1734220557.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1734220557 = $("a[id='1734220557']");
#                 var cell_1734220557 = link_1734220557.parents("div.cell:first");
#                 if (cell_1734220557.length == 0) {
#                     cell_1734220557 = link_1734220557.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1734220557 = cell_1734220557.children("div.input");
#                 if (input_1734220557.length == 0) {
#                     input_1734220557 = cell_1734220557.prev("div.nbinput");
#                 }
#                 input_1734220557.hide();
#
#                 toggle_input_1734220557 = function() {
#                     if (input_1734220557.is(':hidden')) {
#                         input_1734220557.slideDown();
#                         link_1734220557[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1734220557.slideUp();
#                         link_1734220557[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="15858669" href="javascript:toggle_input_15858669()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_15858669;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_15858669 = document.getElementById("15858669");
#                 var cell = link_15858669;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_15858669;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_15858669 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_15858669 = cell.previousElementSibling;
#                 }
#                 input_15858669.style.display = "none"; // hide
#
#                 toggle_input_15858669 = function() {
#                     if (input_15858669.style.display == "none") {
#                         input_15858669.style.display = ""; // show
#                         link_15858669.innerHTML = "Hide Input";
#                     } else {
#                         input_15858669.style.display = "none"; // hide
#                         link_15858669.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_15858669 = $("a[id='15858669']");
#                 var cell_15858669 = link_15858669.parents("div.cell:first");
#                 if (cell_15858669.length == 0) {
#                     cell_15858669 = link_15858669.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_15858669 = cell_15858669.children("div.input");
#                 if (input_15858669.length == 0) {
#                     input_15858669 = cell_15858669.prev("div.nbinput");
#                 }
#                 input_15858669.hide();
#
#                 toggle_input_15858669 = function() {
#                     if (input_15858669.is(':hidden')) {
#                         input_15858669.slideDown();
#                         link_15858669[0].innerHTML = "Hide Input";
#                     } else {
#                         input_15858669.slideUp();
#                         link_15858669[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="96388723" href="javascript:toggle_input_96388723()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_96388723;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_96388723 = document.getElementById("96388723");
#                 var cell = link_96388723;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_96388723;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_96388723 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_96388723 = cell.previousElementSibling;
#                 }
#                 input_96388723.style.display = "none"; // hide
#
#                 toggle_input_96388723 = function() {
#                     if (input_96388723.style.display == "none") {
#                         input_96388723.style.display = ""; // show
#                         link_96388723.innerHTML = "Hide Input";
#                     } else {
#                         input_96388723.style.display = "none"; // hide
#                         link_96388723.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_96388723 = $("a[id='96388723']");
#                 var cell_96388723 = link_96388723.parents("div.cell:first");
#                 if (cell_96388723.length == 0) {
#                     cell_96388723 = link_96388723.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_96388723 = cell_96388723.children("div.input");
#                 if (input_96388723.length == 0) {
#                     input_96388723 = cell_96388723.prev("div.nbinput");
#                 }
#                 input_96388723.hide();
#
#                 toggle_input_96388723 = function() {
#                     if (input_96388723.is(':hidden')) {
#                         input_96388723.slideDown();
#                         link_96388723[0].innerHTML = "Hide Input";
#                     } else {
#                         input_96388723.slideUp();
#                         link_96388723[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="645467518" href="javascript:toggle_input_645467518()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_645467518;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_645467518 = document.getElementById("645467518");
#                 var cell = link_645467518;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_645467518;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_645467518 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_645467518 = cell.previousElementSibling;
#                 }
#                 input_645467518.style.display = "none"; // hide
#
#                 toggle_input_645467518 = function() {
#                     if (input_645467518.style.display == "none") {
#                         input_645467518.style.display = ""; // show
#                         link_645467518.innerHTML = "Hide Input";
#                     } else {
#                         input_645467518.style.display = "none"; // hide
#                         link_645467518.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_645467518 = $("a[id='645467518']");
#                 var cell_645467518 = link_645467518.parents("div.cell:first");
#                 if (cell_645467518.length == 0) {
#                     cell_645467518 = link_645467518.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_645467518 = cell_645467518.children("div.input");
#                 if (input_645467518.length == 0) {
#                     input_645467518 = cell_645467518.prev("div.nbinput");
#                 }
#                 input_645467518.hide();
#
#                 toggle_input_645467518 = function() {
#                     if (input_645467518.is(':hidden')) {
#                         input_645467518.slideDown();
#                         link_645467518[0].innerHTML = "Hide Input";
#                     } else {
#                         input_645467518.slideUp();
#                         link_645467518[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
